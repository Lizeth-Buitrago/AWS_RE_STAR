# %%
print ("hola")

# %%
Nombre = "Zootopia"
Anio = 2026
Visto = True
print("La película", Nombre, "se estrenará en el año", Anio, "y es", Visto, "que la he visto.")
# Out:
# La película Zootopia se estrenará en el año 2026 y es True que la he visto.

# %%
# Listas de datos
peliculas = [
    "The Shawshank Redemption",
    "The Dark Knight",
    "Inception",
    "Pulp Fiction",
    "The Matrix",
    "Interstellar",
    "Parasite",
    "Gladiator",
    "Titanic",
    "The Lord of the Rings: The Fellowship of the Ring"
]

anios = [
    1994,
    2008,
    2010,
    1994,
    1999,
    2014,
    2019,
    2000,
    1997,
    2001
]

vistas = [
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False
]

# Mostrar resultados
for i in range(len(peliculas)):
    estado = "Ya la viste ✅" if vistas[i] else "No la has visto ❌"
    print(f"{peliculas[i]} ({anios[i]}) - {estado}")
# Out:
# The Shawshank Redemption (1994) - Ya la viste ✅
# The Dark Knight (2008) - No la has visto ❌
# Inception (2010) - Ya la viste ✅
# Pulp Fiction (1994) - No la has visto ❌
# The Matrix (1999) - Ya la viste ✅
# Interstellar (2014) - No la has visto ❌
# Parasite (2019) - Ya la viste ✅
# Gladiator (2000) - No la has visto ❌
# Titanic (1997) - Ya la viste ✅
# The Lord of the Rings: The Fellowship of the Ring (2001) - No la has visto ❌
